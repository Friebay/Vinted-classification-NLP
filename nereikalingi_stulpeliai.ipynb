# %%
import pandas as pd

# %%
data = pd.read_csv("daiktai.csv", sep="ʃ", on_bad_lines='skip')
# Out:
# C:\Users\zabit\AppData\Local\Temp\ipykernel_15540\236887269.py:1: ParserWarning: Falling back to the 'python' engine because the separator encoded in utf-8 is > 1 char long, and the 'c' engine does not support such separators; you can avoid this warning by specifying engine='python'.
#   data = pd.read_csv("daiktai.csv", sep="ʃ", on_bad_lines='skip')

# %%
daiktai_cleaned = data[['item_title', 'item_description', 'item_country', 'Sub_Category_1', 'Sub_Category_2']]
daiktai_cleaned.to_csv('daiktai_cleaned.csv', index=False, sep='ʃ')
